# %% [markdown]
# <a href="https://colab.research.google.com/github/peddlem25/StockPredictor/blob/master/regression_lines_predict_stock_prices_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is a regression lines to predict stock prices using Python
#
# GE Stock price currntly Trading at $8.80 Sept 4, 2019

# %% [markdown]
# First let's import all of the necessary packages we need, which include NumPy, Pandas, Matplotlib, Scikit-learn and Keras/Tensorflow.

# %%
# Import necessary packages
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Dense
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import Huber
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %% [markdown]
# I have exported the GE stock price data to my personal Dropbox and will be downloading it locally.

# %%
# Download the data and store it
# GE stock since the beginning
# !wget -O GE.csv https://www.dropbox.com/s/5dsz5n1tkceli7b/GE.csv?dl=0
# Out:
# --2019-09-04 16:42:29--  https://www.dropbox.com/s/5dsz5n1tkceli7b/GE.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/5dsz5n1tkceli7b/GE.csv [following]
# --2019-09-04 16:42:34--  https://www.dropbox.com/s/raw/5dsz5n1tkceli7b/GE.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7705a421e0e3a554496f8311fc.dl.dropboxusercontent.com/cd/0/inline/An4-7dU0AzogLX4yjdEKjYZBORcwukINwjyG2ode0iRcovdDfYASe5zAZWCppxxowQ9v0x9U712u5_ieHSwGqXCewx8c1JHptqIdydiYqJv3XLIwQRcRAVIB7SLjU803g8A/file# [following]
# --2019-09-04 16:42:34--  https://uc7705a421e0e3a554496f8311fc.dl.dropboxusercontent.com/cd/0/inline/An4-7dU0AzogLX4yjdEKjYZBORcwukINwjyG2ode0iRcovdDfYASe5zAZWCppxxowQ9v0x9U712u5_ieHSwGqXCewx8c1JHptqIdydiYqJv3XLIwQRcRAVIB7SLjU803g8A/file
# Resolving uc7705a421e0e3a554496f8311fc.dl.dropboxusercontent.com (uc7705a421e0e3a554496f8311fc.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to uc7705a421e0e3a554496f8311fc.dl.dropboxusercontent.com (uc7705a421e0e3a554496f8311fc.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87560 (86K) [text/plain]
# Saving to: ‘GE.csv’
#
# GE.csv              100%[===================>]  85.51K  --.-KB/s    in 0.04s
#
# 2019-09-04 16:42:35 (2.11 MB/s) - ‘GE.csv’ saved [87560/87560]

# %% [markdown]
# Use Pandas to read in the data and set the independent variable to be the *Date*.  Let's also take a look at the first few entries

# %%
df = pd.read_csv('GE.csv')

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-09-04  24.990385  25.125000  24.894230  24.961538  21.241156  27967400
# 2014-09-05  24.903847  25.096153  24.807692  25.096153  21.355715  21883200
# 2014-09-08  25.134615  25.259615  25.057692  25.076923  21.339350  21194800
# 2014-09-09  25.067308  25.105770  24.855770  24.903847  21.192064  22533000
# 2014-09-10  24.990385  25.028847  24.855770  24.951923  21.232977  19874400

# %% [markdown]
# Let's take a look at how the prices looks like each day since the beginning up to this point with the date on the x-axis and the price on the y-axis.

# %%
df['Adj Close'].plot(label='GE', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# To make this more robust to noise and to leverage past values, we will not use the date to predict the stock prices, but we will use batches of 32 prices where each training example, we leverage 32 prices from the past to predict the price on the 33rd day.  We will thus have $N - 32$ training examples with $N$ being the number of days we've downloaded for the stock data.  We will thus create a 2D matrix of training samples with each row being the prices 32 consecutive days in the past with the price to predict being the current day.

# %%
window_size = 32 # Allow us to look at 32 days into the past
# Prepare the data so that we have 32 day windows and predict what the next day should be

# Get indices of access for the data
num_samples = len(df) - window_size
indices = np.arange(num_samples).astype(np.int)[:,None] + np.arange(window_size + 1).astype(np.int)

# %%
data = df['Adj Close'].values[indices] # Create the 2D matrix of training samples

# %% [markdown]
# We create a 2D matrix such that we have 33 columns per example.  The training samples will be the first 32 columns with the target variable being the last column.

# %%
X = data[:,:-1] # Each row represents 32 days in the past
y = data[:,-1] # Each output value represents the 33rd day

# %% [markdown]
# Perform train/test split such that the first 80% of the prices is the training set and the last 20% of the prices is the test dataset.  We will train on the training set and test the performance on the test set to see how well we can forecast the price for Tesla stock.

# %%
# Train and test split
split_fraction = 0.8
ind_split = int(split_fraction * num_samples)
X_train = X[:ind_split]
y_train = y[:ind_split]
X_test = X[ind_split:]
y_test = y[ind_split:]

# %% [markdown]
# # Method #1 - Ridge Regression
#
# We will use the Ridge Regression method from Scikit-learn where we'll train and perform inference on the training and test data respectively.  Let's also plot how it compares with the actual data for both training and test.

# %%
# Train
ridge_model = Ridge()
ridge_model.fit(X_train, y_train)

# Infer
y_pred_train_ridge = ridge_model.predict(X_train)
y_pred_ridge = ridge_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_ridge['Adj Close Train'] = y_pred_train_ridge[:-window_size]
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# OK... not bad and very frighteningly close.  We may be overfitting.  Let's check out the test data.

# %%
# Same for the test
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_ridge['Adj Close Test'] = y_pred_ridge
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# **Wow**... ok let's move on.
#
# # Method #2 - Gradient Boosting Trees
#
# Let's apply the same methodology from Method #1 to Gradient Boosting Trees in Scikit-learn.

# %%
# Model #2 - Gradient Boosting Trees
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)

# Infer
y_pred_train_gb = gb_model.predict(X_train)
y_pred_gb = gb_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_gb['Adj Close Train'] = y_pred_train_gb[:-window_size]
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again... frighteningly similar.  Let's check the test data.

# %%
# Same for the test
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_gb['Adj Close Test'] = y_pred_gb
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# The results here make sense.  Since trees performing majority voting so there's no interpolation involved, we can see at points of high curvature, it doesn't do so well but the general trend is correct.
#
# # Method #3 - Using neural networks with 1D convolutional and LSTM layers
#
# The last method we'll use is a neural network based one using Keras / Tensorflow.  We use a stack of Conv1D and LSTM layers, followed by Dense layers lastly followed by a linear layer to predict the stock price.

# %%
# Model #3 - Using RNNs
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])

keras_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0904 16:50:40.681038 140028592023424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0904 16:50:40.725569 140028592023424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0904 16:50:40.735080 140028592023424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 32, 128)           768
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 128)           82048
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32, 128)           131584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 358,465
# Trainable params: 358,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This is a technique to find the optimal learning rate for the neural network.  Specifically we gradually increase the learning rate at each epoch, recording the loss for each then choosing the learning rate that has the smallest loss overall.
#
# Also, neural networks learn better when the data is normalized so we will normalize the data to the $[-1,1]$ range by using Scikit-learn's `MinMaxScaler`.  Therefore, we need to find apply this scaling on all of the price data, then decompose it into the training and test sets again.

# %%
# First figure out the right learning rate
lr_schedule = LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = SGD(lr=1e-8, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
# Scale the data due to LSTM units
scaler = MinMaxScaler(feature_range=(-1, 1))
data_transform = scaler.fit_transform(df['Adj Close'].values[:,None])
data_transform = data_transform[indices]
X2 = data_transform[:,:-1]
y2 = data_transform[:,-1]
X_train_reshape = X2[:ind_split]
y_train_reshape = y2[:ind_split]
X_test_reshape = X2[ind_split:]
y_test_reshape = y2[ind_split:]
# Out:
# W0904 16:51:21.904755 140028592023424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# We now try and find the optimal learning rate.  If you're using Google Colab, this will take ~4 minutes.

# %%
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, callbacks=[lr_schedule], validation_data=(X_test_reshape, y_test_reshape))
# Out:
# W0904 16:51:58.754665 140028592023424 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0904 16:52:00.105559 140028592023424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0904 16:52:00.166329 140028592023424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 980 samples, validate on 246 samples
# Epoch 1/250
# 980/980 [==============================] - 5s 5ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 2/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 3/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 4/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 5/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 6/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 7/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 8/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 9/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 10/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 11/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 12/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 13/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 14/250
# 980/980 [==============================] - 2s 3ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 15/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 16/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 17/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 18/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 19/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1898 - mean_absolute_error: 0.5649 - val_loss: 0.2777 - val_mean_absolute_error: 0.7344
# Epoch 20/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5649 - val_loss: 0.2778 - val_mean_absolute_error: 0.7344
# Epoch 21/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5649 - val_loss: 0.2778 - val_mean_absolute_error: 0.7344
# Epoch 22/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5649 - val_loss: 0.2778 - val_mean_absolute_error: 0.7344
# Epoch 23/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5648 - val_loss: 0.2778 - val_mean_absolute_error: 0.7344
# Epoch 24/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5648 - val_loss: 0.2778 - val_mean_absolute_error: 0.7344
# Epoch 25/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5648 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 26/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5648 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 27/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5648 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 28/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1897 - mean_absolute_error: 0.5648 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 29/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1896 - mean_absolute_error: 0.5647 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 30/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1896 - mean_absolute_error: 0.5647 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 31/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1896 - mean_absolute_error: 0.5647 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 32/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1896 - mean_absolute_error: 0.5646 - val_loss: 0.2778 - val_mean_absolute_error: 0.7345
# Epoch 33/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1896 - mean_absolute_error: 0.5646 - val_loss: 0.2779 - val_mean_absolute_error: 0.7346
# Epoch 34/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1895 - mean_absolute_error: 0.5646 - val_loss: 0.2779 - val_mean_absolute_error: 0.7346
# Epoch 35/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1895 - mean_absolute_error: 0.5645 - val_loss: 0.2779 - val_mean_absolute_error: 0.7346
# Epoch 36/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1894 - mean_absolute_error: 0.5644 - val_loss: 0.2779 - val_mean_absolute_error: 0.7346
# Epoch 37/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1894 - mean_absolute_error: 0.5644 - val_loss: 0.2779 - val_mean_absolute_error: 0.7347
# Epoch 38/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1894 - mean_absolute_error: 0.5643 - val_loss: 0.2780 - val_mean_absolute_error: 0.7347
# Epoch 39/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1893 - mean_absolute_error: 0.5642 - val_loss: 0.2780 - val_mean_absolute_error: 0.7348
# Epoch 40/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1892 - mean_absolute_error: 0.5641 - val_loss: 0.2780 - val_mean_absolute_error: 0.7348
# Epoch 41/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1892 - mean_absolute_error: 0.5640 - val_loss: 0.2781 - val_mean_absolute_error: 0.7348
# Epoch 42/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1891 - mean_absolute_error: 0.5639 - val_loss: 0.2781 - val_mean_absolute_error: 0.7349
# Epoch 43/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1890 - mean_absolute_error: 0.5638 - val_loss: 0.2781 - val_mean_absolute_error: 0.7350
# Epoch 44/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1889 - mean_absolute_error: 0.5637 - val_loss: 0.2782 - val_mean_absolute_error: 0.7350
# Epoch 45/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1888 - mean_absolute_error: 0.5635 - val_loss: 0.2783 - val_mean_absolute_error: 0.7351
# Epoch 46/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1887 - mean_absolute_error: 0.5633 - val_loss: 0.2783 - val_mean_absolute_error: 0.7352
# Epoch 47/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1885 - mean_absolute_error: 0.5631 - val_loss: 0.2784 - val_mean_absolute_error: 0.7353
# Epoch 48/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1884 - mean_absolute_error: 0.5629 - val_loss: 0.2785 - val_mean_absolute_error: 0.7354
# Epoch 49/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1882 - mean_absolute_error: 0.5626 - val_loss: 0.2786 - val_mean_absolute_error: 0.7356
# Epoch 50/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1880 - mean_absolute_error: 0.5624 - val_loss: 0.2787 - val_mean_absolute_error: 0.7357
# Epoch 51/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1878 - mean_absolute_error: 0.5620 - val_loss: 0.2788 - val_mean_absolute_error: 0.7359
# Epoch 52/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1875 - mean_absolute_error: 0.5617 - val_loss: 0.2789 - val_mean_absolute_error: 0.7360
# Epoch 53/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1872 - mean_absolute_error: 0.5613 - val_loss: 0.2791 - val_mean_absolute_error: 0.7362
# Epoch 54/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1869 - mean_absolute_error: 0.5608 - val_loss: 0.2792 - val_mean_absolute_error: 0.7365
# Epoch 55/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1866 - mean_absolute_error: 0.5604 - val_loss: 0.2794 - val_mean_absolute_error: 0.7367
# Epoch 56/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1862 - mean_absolute_error: 0.5598 - val_loss: 0.2796 - val_mean_absolute_error: 0.7370
# Epoch 57/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1858 - mean_absolute_error: 0.5592 - val_loss: 0.2798 - val_mean_absolute_error: 0.7373
# Epoch 58/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1853 - mean_absolute_error: 0.5585 - val_loss: 0.2801 - val_mean_absolute_error: 0.7377
# Epoch 59/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1847 - mean_absolute_error: 0.5577 - val_loss: 0.2804 - val_mean_absolute_error: 0.7381
# Epoch 60/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1841 - mean_absolute_error: 0.5568 - val_loss: 0.2807 - val_mean_absolute_error: 0.7385
# Epoch 61/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1835 - mean_absolute_error: 0.5558 - val_loss: 0.2810 - val_mean_absolute_error: 0.7390
# Epoch 62/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1827 - mean_absolute_error: 0.5547 - val_loss: 0.2814 - val_mean_absolute_error: 0.7395
# Epoch 63/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1819 - mean_absolute_error: 0.5535 - val_loss: 0.2819 - val_mean_absolute_error: 0.7402
# Epoch 64/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1809 - mean_absolute_error: 0.5521 - val_loss: 0.2824 - val_mean_absolute_error: 0.7408
# Epoch 65/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1799 - mean_absolute_error: 0.5505 - val_loss: 0.2829 - val_mean_absolute_error: 0.7416
# Epoch 66/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1787 - mean_absolute_error: 0.5488 - val_loss: 0.2835 - val_mean_absolute_error: 0.7424
# Epoch 67/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1774 - mean_absolute_error: 0.5469 - val_loss: 0.2842 - val_mean_absolute_error: 0.7434
# Epoch 68/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1760 - mean_absolute_error: 0.5447 - val_loss: 0.2850 - val_mean_absolute_error: 0.7444
# Epoch 69/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1744 - mean_absolute_error: 0.5423 - val_loss: 0.2858 - val_mean_absolute_error: 0.7456
# Epoch 70/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1726 - mean_absolute_error: 0.5396 - val_loss: 0.2868 - val_mean_absolute_error: 0.7469
# Epoch 71/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1707 - mean_absolute_error: 0.5366 - val_loss: 0.2878 - val_mean_absolute_error: 0.7484
# Epoch 72/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1685 - mean_absolute_error: 0.5333 - val_loss: 0.2890 - val_mean_absolute_error: 0.7500
# Epoch 73/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1662 - mean_absolute_error: 0.5296 - val_loss: 0.2903 - val_mean_absolute_error: 0.7517
# Epoch 74/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1636 - mean_absolute_error: 0.5255 - val_loss: 0.2917 - val_mean_absolute_error: 0.7537
# Epoch 75/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1607 - mean_absolute_error: 0.5209 - val_loss: 0.2933 - val_mean_absolute_error: 0.7558
# Epoch 76/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1576 - mean_absolute_error: 0.5158 - val_loss: 0.2950 - val_mean_absolute_error: 0.7581
# Epoch 77/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1542 - mean_absolute_error: 0.5102 - val_loss: 0.2968 - val_mean_absolute_error: 0.7606
# Epoch 78/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1505 - mean_absolute_error: 0.5040 - val_loss: 0.2989 - val_mean_absolute_error: 0.7634
# Epoch 79/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1465 - mean_absolute_error: 0.4971 - val_loss: 0.3010 - val_mean_absolute_error: 0.7663
# Epoch 80/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1421 - mean_absolute_error: 0.4897 - val_loss: 0.3034 - val_mean_absolute_error: 0.7694
# Epoch 81/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1376 - mean_absolute_error: 0.4814 - val_loss: 0.3059 - val_mean_absolute_error: 0.7728
# Epoch 82/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1327 - mean_absolute_error: 0.4726 - val_loss: 0.3086 - val_mean_absolute_error: 0.7764
# Epoch 83/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1274 - mean_absolute_error: 0.4626 - val_loss: 0.3115 - val_mean_absolute_error: 0.7802
# Epoch 84/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1219 - mean_absolute_error: 0.4521 - val_loss: 0.3144 - val_mean_absolute_error: 0.7841
# Epoch 85/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1163 - mean_absolute_error: 0.4406 - val_loss: 0.3175 - val_mean_absolute_error: 0.7882
# Epoch 86/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1103 - mean_absolute_error: 0.4280 - val_loss: 0.3205 - val_mean_absolute_error: 0.7921
# Epoch 87/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.1042 - mean_absolute_error: 0.4145 - val_loss: 0.3234 - val_mean_absolute_error: 0.7960
# Epoch 88/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0979 - mean_absolute_error: 0.3999 - val_loss: 0.3261 - val_mean_absolute_error: 0.7995
# Epoch 89/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0917 - mean_absolute_error: 0.3847 - val_loss: 0.3285 - val_mean_absolute_error: 0.8027
# Epoch 90/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0856 - mean_absolute_error: 0.3689 - val_loss: 0.3304 - val_mean_absolute_error: 0.8053
# Epoch 91/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0796 - mean_absolute_error: 0.3524 - val_loss: 0.3315 - val_mean_absolute_error: 0.8068
# Epoch 92/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0738 - mean_absolute_error: 0.3356 - val_loss: 0.3316 - val_mean_absolute_error: 0.8072
# Epoch 93/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0684 - mean_absolute_error: 0.3186 - val_loss: 0.3304 - val_mean_absolute_error: 0.8059
# Epoch 94/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0632 - mean_absolute_error: 0.3022 - val_loss: 0.3271 - val_mean_absolute_error: 0.8021
# Epoch 95/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0584 - mean_absolute_error: 0.2868 - val_loss: 0.3219 - val_mean_absolute_error: 0.7958
# Epoch 96/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0541 - mean_absolute_error: 0.2722 - val_loss: 0.3142 - val_mean_absolute_error: 0.7863
# Epoch 97/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0501 - mean_absolute_error: 0.2586 - val_loss: 0.3034 - val_mean_absolute_error: 0.7727
# Epoch 98/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0464 - mean_absolute_error: 0.2462 - val_loss: 0.2892 - val_mean_absolute_error: 0.7543
# Epoch 99/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0429 - mean_absolute_error: 0.2344 - val_loss: 0.2717 - val_mean_absolute_error: 0.7311
# Epoch 100/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0395 - mean_absolute_error: 0.2230 - val_loss: 0.2505 - val_mean_absolute_error: 0.7017
# Epoch 101/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0360 - mean_absolute_error: 0.2122 - val_loss: 0.2263 - val_mean_absolute_error: 0.6666
# Epoch 102/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0323 - mean_absolute_error: 0.2007 - val_loss: 0.1994 - val_mean_absolute_error: 0.6252
# Epoch 103/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0286 - mean_absolute_error: 0.1886 - val_loss: 0.1700 - val_mean_absolute_error: 0.5766
# Epoch 104/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0246 - mean_absolute_error: 0.1756 - val_loss: 0.1403 - val_mean_absolute_error: 0.5226
# Epoch 105/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0206 - mean_absolute_error: 0.1612 - val_loss: 0.1109 - val_mean_absolute_error: 0.4634
# Epoch 106/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0167 - mean_absolute_error: 0.1460 - val_loss: 0.0828 - val_mean_absolute_error: 0.3985
# Epoch 107/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0130 - mean_absolute_error: 0.1295 - val_loss: 0.0579 - val_mean_absolute_error: 0.3302
# Epoch 108/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0098 - mean_absolute_error: 0.1127 - val_loss: 0.0369 - val_mean_absolute_error: 0.2593
# Epoch 109/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0956 - val_loss: 0.0212 - val_mean_absolute_error: 0.1895
# Epoch 110/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0805 - val_loss: 0.0107 - val_mean_absolute_error: 0.1241
# Epoch 111/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0687 - val_loss: 0.0052 - val_mean_absolute_error: 0.0740
# Epoch 112/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0623 - val_loss: 0.0033 - val_mean_absolute_error: 0.0623
# Epoch 113/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0603 - val_loss: 0.0035 - val_mean_absolute_error: 0.0703
# Epoch 114/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0608 - val_loss: 0.0041 - val_mean_absolute_error: 0.0778
# Epoch 115/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0617 - val_loss: 0.0042 - val_mean_absolute_error: 0.0794
# Epoch 116/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0616 - val_loss: 0.0039 - val_mean_absolute_error: 0.0758
# Epoch 117/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0607 - val_loss: 0.0034 - val_mean_absolute_error: 0.0700
# Epoch 118/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0600 - val_loss: 0.0032 - val_mean_absolute_error: 0.0655
# Epoch 119/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0596 - val_loss: 0.0032 - val_mean_absolute_error: 0.0629
# Epoch 120/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0596 - val_loss: 0.0033 - val_mean_absolute_error: 0.0619
# Epoch 121/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0594 - val_loss: 0.0032 - val_mean_absolute_error: 0.0622
# Epoch 122/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0592 - val_loss: 0.0032 - val_mean_absolute_error: 0.0629
# Epoch 123/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0590 - val_loss: 0.0032 - val_mean_absolute_error: 0.0637
# Epoch 124/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0588 - val_loss: 0.0031 - val_mean_absolute_error: 0.0640
# Epoch 125/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0587 - val_loss: 0.0031 - val_mean_absolute_error: 0.0634
# Epoch 126/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0585 - val_loss: 0.0031 - val_mean_absolute_error: 0.0625
# Epoch 127/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0583 - val_loss: 0.0031 - val_mean_absolute_error: 0.0620
# Epoch 128/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0580 - val_loss: 0.0031 - val_mean_absolute_error: 0.0617
# Epoch 129/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0578 - val_loss: 0.0032 - val_mean_absolute_error: 0.0611
# Epoch 130/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0575 - val_loss: 0.0031 - val_mean_absolute_error: 0.0611
# Epoch 131/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0573 - val_loss: 0.0031 - val_mean_absolute_error: 0.0609
# Epoch 132/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0570 - val_loss: 0.0032 - val_mean_absolute_error: 0.0599
# Epoch 133/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0566 - val_loss: 0.0032 - val_mean_absolute_error: 0.0597
# Epoch 134/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0563 - val_loss: 0.0031 - val_mean_absolute_error: 0.0596
# Epoch 135/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0560 - val_loss: 0.0031 - val_mean_absolute_error: 0.0591
# Epoch 136/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0560 - val_loss: 0.0031 - val_mean_absolute_error: 0.0589
# Epoch 137/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0558 - val_loss: 0.0033 - val_mean_absolute_error: 0.0593
# Epoch 138/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0553 - val_loss: 0.0031 - val_mean_absolute_error: 0.0586
# Epoch 139/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0576 - val_loss: 0.0032 - val_mean_absolute_error: 0.0588
# Epoch 140/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0564 - val_loss: 0.0035 - val_mean_absolute_error: 0.0606
# Epoch 141/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0563 - val_loss: 0.0031 - val_mean_absolute_error: 0.0579
# Epoch 142/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0579 - val_loss: 0.0033 - val_mean_absolute_error: 0.0597
# Epoch 143/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0531 - val_loss: 0.0035 - val_mean_absolute_error: 0.0610
# Epoch 144/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0552 - val_loss: 0.0028 - val_mean_absolute_error: 0.0561
# Epoch 145/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0561 - val_loss: 0.0039 - val_mean_absolute_error: 0.0663
# Epoch 146/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0587 - val_loss: 0.0030 - val_mean_absolute_error: 0.0568
# Epoch 147/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0690 - val_loss: 0.0038 - val_mean_absolute_error: 0.0657
# Epoch 148/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0741 - val_loss: 0.0024 - val_mean_absolute_error: 0.0528
# Epoch 149/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0063 - mean_absolute_error: 0.0932 - val_loss: 0.0045 - val_mean_absolute_error: 0.0738
# Epoch 150/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0728 - val_loss: 0.0036 - val_mean_absolute_error: 0.0637
# Epoch 151/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0539 - val_loss: 0.0039 - val_mean_absolute_error: 0.0675
# Epoch 152/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0849 - val_loss: 0.0043 - val_mean_absolute_error: 0.0712
# Epoch 153/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0155 - mean_absolute_error: 0.1550 - val_loss: 0.0106 - val_mean_absolute_error: 0.1269
# Epoch 154/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0901 - val_loss: 0.0104 - val_mean_absolute_error: 0.1220
# Epoch 155/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.5174 - mean_absolute_error: 0.7934 - val_loss: 9.3923 - val_mean_absolute_error: 9.8923
# Epoch 156/250
# 980/980 [==============================] - 2s 2ms/step - loss: 10.0333 - mean_absolute_error: 10.5333 - val_loss: 0.7834 - val_mean_absolute_error: 1.2834
# Epoch 157/250
# 980/980 [==============================] - 2s 2ms/step - loss: 18.7521 - mean_absolute_error: 19.2521 - val_loss: 61.5887 - val_mean_absolute_error: 62.0887
# Epoch 158/250
# 980/980 [==============================] - 2s 2ms/step - loss: 53.2771 - mean_absolute_error: 53.7771 - val_loss: 54.0375 - val_mean_absolute_error: 54.5375
# Epoch 159/250
# 980/980 [==============================] - 2s 2ms/step - loss: 28.4527 - mean_absolute_error: 28.9527 - val_loss: 9.1225 - val_mean_absolute_error: 9.6225
# Epoch 160/250
# 980/980 [==============================] - 2s 2ms/step - loss: 27.6065 - mean_absolute_error: 28.1065 - val_loss: 69.9531 - val_mean_absolute_error: 70.4531
# Epoch 161/250
# 980/980 [==============================] - 2s 2ms/step - loss: 78.5828 - mean_absolute_error: 79.0828 - val_loss: 110.2271 - val_mean_absolute_error: 110.7272
# Epoch 162/250
# 980/980 [==============================] - 2s 2ms/step - loss: 119.6174 - mean_absolute_error: 120.1174 - val_loss: 218.0390 - val_mean_absolute_error: 218.5389
# Epoch 163/250
# 980/980 [==============================] - 2s 2ms/step - loss: 118.8744 - mean_absolute_error: 119.3744 - val_loss: 67.7493 - val_mean_absolute_error: 68.2493
# Epoch 164/250
# 980/980 [==============================] - 2s 2ms/step - loss: 49.6917 - mean_absolute_error: 50.1917 - val_loss: 5.7452 - val_mean_absolute_error: 6.2452
# Epoch 165/250
# 980/980 [==============================] - 2s 2ms/step - loss: 65.9872 - mean_absolute_error: 66.4872 - val_loss: 173.0162 - val_mean_absolute_error: 173.5162
# Epoch 166/250
# 980/980 [==============================] - 2s 2ms/step - loss: 149.4469 - mean_absolute_error: 149.9470 - val_loss: 46.1123 - val_mean_absolute_error: 46.6123
# Epoch 167/250
# 980/980 [==============================] - 2s 2ms/step - loss: 35.7555 - mean_absolute_error: 36.1894 - val_loss: 27.6574 - val_mean_absolute_error: 28.1574
# Epoch 168/250
# 980/980 [==============================] - 2s 2ms/step - loss: 35.9064 - mean_absolute_error: 36.4064 - val_loss: 41.3465 - val_mean_absolute_error: 41.8465
# Epoch 169/250
# 980/980 [==============================] - 2s 2ms/step - loss: 44.4080 - mean_absolute_error: 44.9080 - val_loss: 21.4037 - val_mean_absolute_error: 21.9037
# Epoch 170/250
# 980/980 [==============================] - 2s 2ms/step - loss: 84.4198 - mean_absolute_error: 84.9198 - val_loss: 305.6166 - val_mean_absolute_error: 306.1166
# Epoch 171/250
# 980/980 [==============================] - 2s 2ms/step - loss: 238.7000 - mean_absolute_error: 239.2000 - val_loss: 206.0631 - val_mean_absolute_error: 206.5632
# Epoch 172/250
# 980/980 [==============================] - 2s 2ms/step - loss: 134.8419 - mean_absolute_error: 135.3418 - val_loss: 375.3017 - val_mean_absolute_error: 375.8017
# Epoch 173/250
# 980/980 [==============================] - 2s 2ms/step - loss: 323.3547 - mean_absolute_error: 323.8547 - val_loss: 251.1591 - val_mean_absolute_error: 251.6591
# Epoch 174/250
# 980/980 [==============================] - 2s 2ms/step - loss: 293.8441 - mean_absolute_error: 294.3442 - val_loss: 323.7422 - val_mean_absolute_error: 324.2422
# Epoch 175/250
# 980/980 [==============================] - 2s 2ms/step - loss: 213.3763 - mean_absolute_error: 213.8763 - val_loss: 465.5127 - val_mean_absolute_error: 466.0128
# Epoch 176/250
# 980/980 [==============================] - 2s 2ms/step - loss: 416.7429 - mean_absolute_error: 417.2430 - val_loss: 483.6279 - val_mean_absolute_error: 484.1279
# Epoch 177/250
# 980/980 [==============================] - 2s 2ms/step - loss: 411.0619 - mean_absolute_error: 411.5619 - val_loss: 286.9762 - val_mean_absolute_error: 287.4763
# Epoch 178/250
# 980/980 [==============================] - 2s 2ms/step - loss: 394.0179 - mean_absolute_error: 394.5178 - val_loss: 459.7561 - val_mean_absolute_error: 460.2562
# Epoch 179/250
# 980/980 [==============================] - 2s 2ms/step - loss: 475.3752 - mean_absolute_error: 475.8752 - val_loss: 899.3807 - val_mean_absolute_error: 899.8804
# Epoch 180/250
# 980/980 [==============================] - 2s 2ms/step - loss: 587.7307 - mean_absolute_error: 588.2308 - val_loss: 177.7117 - val_mean_absolute_error: 178.2117
# Epoch 181/250
# 980/980 [==============================] - 2s 2ms/step - loss: 668.8313 - mean_absolute_error: 669.3313 - val_loss: 414.0099 - val_mean_absolute_error: 414.5099
# Epoch 182/250
# 980/980 [==============================] - 2s 2ms/step - loss: 537.5238 - mean_absolute_error: 538.0238 - val_loss: 1511.3252 - val_mean_absolute_error: 1511.8254
# Epoch 183/250
# 980/980 [==============================] - 2s 2ms/step - loss: 840.4521 - mean_absolute_error: 840.9522 - val_loss: 7.1799 - val_mean_absolute_error: 7.6799
# Epoch 184/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1062.5913 - mean_absolute_error: 1063.0913 - val_loss: 338.7685 - val_mean_absolute_error: 339.2683
# Epoch 185/250
# 980/980 [==============================] - 2s 2ms/step - loss: 332.3365 - mean_absolute_error: 332.8365 - val_loss: 528.3652 - val_mean_absolute_error: 528.8652
# Epoch 186/250
# 980/980 [==============================] - 2s 2ms/step - loss: 962.7317 - mean_absolute_error: 963.2316 - val_loss: 978.3482 - val_mean_absolute_error: 978.8484
# Epoch 187/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1202.8128 - mean_absolute_error: 1203.3125 - val_loss: 1027.7147 - val_mean_absolute_error: 1028.2147
# Epoch 188/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1172.7075 - mean_absolute_error: 1173.2075 - val_loss: 3091.7761 - val_mean_absolute_error: 3092.2764
# Epoch 189/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1637.4693 - mean_absolute_error: 1637.9695 - val_loss: 241.6698 - val_mean_absolute_error: 242.1698
# Epoch 190/250
# 980/980 [==============================] - 2s 2ms/step - loss: 424.7860 - mean_absolute_error: 425.2860 - val_loss: 692.1971 - val_mean_absolute_error: 692.6969
# Epoch 191/250
# 980/980 [==============================] - 2s 2ms/step - loss: 554.1810 - mean_absolute_error: 554.6810 - val_loss: 623.6536 - val_mean_absolute_error: 624.1537
# Epoch 192/250
# 980/980 [==============================] - 2s 2ms/step - loss: 653.4284 - mean_absolute_error: 653.9284 - val_loss: 170.1172 - val_mean_absolute_error: 170.6172
# Epoch 193/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1210.2858 - mean_absolute_error: 1210.7859 - val_loss: 4071.9900 - val_mean_absolute_error: 4072.4893
# Epoch 194/250
# 980/980 [==============================] - 2s 2ms/step - loss: 3385.0387 - mean_absolute_error: 3385.5381 - val_loss: 3242.7742 - val_mean_absolute_error: 3243.2749
# Epoch 195/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1835.4311 - mean_absolute_error: 1835.9310 - val_loss: 832.5682 - val_mean_absolute_error: 833.0681
# Epoch 196/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1765.5936 - mean_absolute_error: 1766.0935 - val_loss: 4689.1699 - val_mean_absolute_error: 4689.6680
# Epoch 197/250
# 980/980 [==============================] - 2s 2ms/step - loss: 4993.3209 - mean_absolute_error: 4993.8205 - val_loss: 6729.4268 - val_mean_absolute_error: 6729.9292
# Epoch 198/250
# 980/980 [==============================] - 2s 2ms/step - loss: 7572.2310 - mean_absolute_error: 7572.7313 - val_loss: 14052.7910 - val_mean_absolute_error: 14053.2959
# Epoch 199/250
# 980/980 [==============================] - 2s 2ms/step - loss: 7539.1416 - mean_absolute_error: 7539.6424 - val_loss: 3909.4836 - val_mean_absolute_error: 3909.9829
# Epoch 200/250
# 980/980 [==============================] - 2s 2ms/step - loss: 3174.1506 - mean_absolute_error: 3174.6512 - val_loss: 144.7811 - val_mean_absolute_error: 145.2811
# Epoch 201/250
# 980/980 [==============================] - 2s 2ms/step - loss: 4240.8023 - mean_absolute_error: 4241.3027 - val_loss: 10795.6348 - val_mean_absolute_error: 10796.1357
# Epoch 202/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9418.2374 - mean_absolute_error: 9418.7369 - val_loss: 3029.0396 - val_mean_absolute_error: 3029.5403
# Epoch 203/250
# 980/980 [==============================] - 2s 2ms/step - loss: 3871.5793 - mean_absolute_error: 3872.0791 - val_loss: 12252.2471 - val_mean_absolute_error: 12252.7422
# Epoch 204/250
# 980/980 [==============================] - 2s 2ms/step - loss: 11165.7269 - mean_absolute_error: 11166.2278 - val_loss: 12925.3779 - val_mean_absolute_error: 12925.8818
# Epoch 205/250
# 980/980 [==============================] - 2s 2ms/step - loss: 5618.6486 - mean_absolute_error: 5619.1483 - val_loss: 1376.0181 - val_mean_absolute_error: 1376.5181
# Epoch 206/250
# 980/980 [==============================] - 2s 2ms/step - loss: 8252.7530 - mean_absolute_error: 8253.2533 - val_loss: 17131.0645 - val_mean_absolute_error: 17131.5703
# Epoch 207/250
# 980/980 [==============================] - 2s 2ms/step - loss: 15471.3840 - mean_absolute_error: 15471.8823 - val_loss: 9543.6240 - val_mean_absolute_error: 9544.1211
# Epoch 208/250
# 980/980 [==============================] - 2s 2ms/step - loss: 4945.2029 - mean_absolute_error: 4945.7027 - val_loss: 1123.1133 - val_mean_absolute_error: 1123.6133
# Epoch 209/250
# 980/980 [==============================] - 2s 2ms/step - loss: 7818.2401 - mean_absolute_error: 7818.7387 - val_loss: 22095.0684 - val_mean_absolute_error: 22095.5723
# Epoch 210/250
# 980/980 [==============================] - 2s 2ms/step - loss: 21770.8790 - mean_absolute_error: 21771.3835 - val_loss: 26456.1914 - val_mean_absolute_error: 26456.6973
# Epoch 211/250
# 980/980 [==============================] - 2s 2ms/step - loss: 11236.4008 - mean_absolute_error: 11236.9028 - val_loss: 2306.2119 - val_mean_absolute_error: 2306.7129
# Epoch 212/250
# 980/980 [==============================] - 2s 2ms/step - loss: 16960.9850 - mean_absolute_error: 16961.4845 - val_loss: 33016.0469 - val_mean_absolute_error: 33016.5352
# Epoch 213/250
# 980/980 [==============================] - 2s 2ms/step - loss: 30184.3912 - mean_absolute_error: 30184.8852 - val_loss: 20684.0879 - val_mean_absolute_error: 20684.5859
# Epoch 214/250
# 980/980 [==============================] - 2s 2ms/step - loss: 30654.7831 - mean_absolute_error: 30655.2799 - val_loss: 42839.4531 - val_mean_absolute_error: 42839.9375
# Epoch 215/250
# 980/980 [==============================] - 2s 2ms/step - loss: 18206.7764 - mean_absolute_error: 18207.2782 - val_loss: 4243.2754 - val_mean_absolute_error: 4243.7769
# Epoch 216/250
# 980/980 [==============================] - 2s 2ms/step - loss: 17636.9186 - mean_absolute_error: 17637.4200 - val_loss: 46956.0117 - val_mean_absolute_error: 46956.5273
# Epoch 217/250
# 980/980 [==============================] - 2s 2ms/step - loss: 49290.9620 - mean_absolute_error: 49291.4635 - val_loss: 64518.2617 - val_mean_absolute_error: 64518.7695
# Epoch 218/250
# 980/980 [==============================] - 2s 2ms/step - loss: 76027.7441 - mean_absolute_error: 76028.2464 - val_loss: 145098.0156 - val_mean_absolute_error: 145098.5156
# Epoch 219/250
# 980/980 [==============================] - 2s 2ms/step - loss: 75321.6670 - mean_absolute_error: 75322.1555 - val_loss: 34628.8086 - val_mean_absolute_error: 34629.3086
# Epoch 220/250
# 980/980 [==============================] - 2s 2ms/step - loss: 32060.8018 - mean_absolute_error: 32061.3029 - val_loss: 5294.6880 - val_mean_absolute_error: 5295.1895
# Epoch 221/250
# 980/980 [==============================] - 2s 2ms/step - loss: 32896.3960 - mean_absolute_error: 32896.8918 - val_loss: 52510.3828 - val_mean_absolute_error: 52510.9023
# Epoch 222/250
# 980/980 [==============================] - 2s 2ms/step - loss: 35847.7866 - mean_absolute_error: 35848.2865 - val_loss: 84844.9062 - val_mean_absolute_error: 84845.3984
# Epoch 223/250
# 980/980 [==============================] - 2s 2ms/step - loss: 106239.3943 - mean_absolute_error: 106239.9075 - val_loss: 172276.8125 - val_mean_absolute_error: 172277.2969
# Epoch 224/250
# 980/980 [==============================] - 2s 2ms/step - loss: 148213.4288 - mean_absolute_error: 148213.9125 - val_loss: 223196.9688 - val_mean_absolute_error: 223197.4375
# Epoch 225/250
# 980/980 [==============================] - 2s 2ms/step - loss: 150877.2424 - mean_absolute_error: 150877.7295 - val_loss: 150343.5156 - val_mean_absolute_error: 150344.0625
# Epoch 226/250
# 980/980 [==============================] - 2s 2ms/step - loss: 175791.8710 - mean_absolute_error: 175792.3630 - val_loss: 314826.4375 - val_mean_absolute_error: 314826.9688
# Epoch 227/250
# 980/980 [==============================] - 2s 2ms/step - loss: 196586.9300 - mean_absolute_error: 196587.4334 - val_loss: 176889.1875 - val_mean_absolute_error: 176889.7188
# Epoch 228/250
# 980/980 [==============================] - 2s 2ms/step - loss: 217390.9899 - mean_absolute_error: 217391.4450 - val_loss: 394648.0938 - val_mean_absolute_error: 394648.8750
# Epoch 229/250
# 980/980 [==============================] - 2s 2ms/step - loss: 249618.1869 - mean_absolute_error: 249618.7085 - val_loss: 233621.4688 - val_mean_absolute_error: 233621.9062
# Epoch 230/250
# 980/980 [==============================] - 2s 2ms/step - loss: 272722.6404 - mean_absolute_error: 272723.1219 - val_loss: 479842.0625 - val_mean_absolute_error: 479842.7812
# Epoch 231/250
# 980/980 [==============================] - 2s 2ms/step - loss: 314437.5380 - mean_absolute_error: 314438.0135 - val_loss: 315078.4062 - val_mean_absolute_error: 315078.9375
# Epoch 232/250
# 980/980 [==============================] - 2s 2ms/step - loss: 343655.8513 - mean_absolute_error: 343656.3699 - val_loss: 580510.8750 - val_mean_absolute_error: 580511.1250
# Epoch 233/250
# 980/980 [==============================] - 2s 2ms/step - loss: 395203.8366 - mean_absolute_error: 395204.3214 - val_loss: 421946.9688 - val_mean_absolute_error: 421947.1875
# Epoch 234/250
# 980/980 [==============================] - 2s 2ms/step - loss: 433504.4263 - mean_absolute_error: 433504.8592 - val_loss: 704410.1875 - val_mean_absolute_error: 704411.0625
# Epoch 235/250
# 980/980 [==============================] - 2s 2ms/step - loss: 496522.5745 - mean_absolute_error: 496523.0314 - val_loss: 558345.9375 - val_mean_absolute_error: 558346.1250
# Epoch 236/250
# 980/980 [==============================] - 2s 2ms/step - loss: 546853.2444 - mean_absolute_error: 546853.6712 - val_loss: 859171.3750 - val_mean_absolute_error: 859171.7500
# Epoch 237/250
# 980/980 [==============================] - 2s 2ms/step - loss: 623920.1847 - mean_absolute_error: 623920.7005 - val_loss: 730862.0625 - val_mean_absolute_error: 730862.5625
# Epoch 238/250
# 980/980 [==============================] - 2s 2ms/step - loss: 689652.5036 - mean_absolute_error: 689653.0092 - val_loss: 1053477.8750 - val_mean_absolute_error: 1053478.1250
# Epoch 239/250
# 980/980 [==============================] - 2s 2ms/step - loss: 784237.3765 - mean_absolute_error: 784238.1536 - val_loss: 948392.0625 - val_mean_absolute_error: 948392.3750
# Epoch 240/250
# 980/980 [==============================] - 2s 2ms/step - loss: 869470.1551 - mean_absolute_error: 869470.4704 - val_loss: 1297869.6250 - val_mean_absolute_error: 1297870.1250
# Epoch 241/250
# 980/980 [==============================] - 2s 2ms/step - loss: 986036.5582 - mean_absolute_error: 986037.0908 - val_loss: 1222394.2500 - val_mean_absolute_error: 1222395.0000
# Epoch 242/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1095865.5541 - mean_absolute_error: 1095866.0893 - val_loss: 1605443.6250 - val_mean_absolute_error: 1605443.7500
# Epoch 243/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1240073.7571 - mean_absolute_error: 1240074.6969 - val_loss: 1567407.8750 - val_mean_absolute_error: 1567408.0000
# Epoch 244/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1380888.8163 - mean_absolute_error: 1380889.1806 - val_loss: 1992612.0000 - val_mean_absolute_error: 1992612.2500
# Epoch 245/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1559883.2888 - mean_absolute_error: 1559883.6480 - val_loss: 2001780.1250 - val_mean_absolute_error: 2001780.5000
# Epoch 246/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1739715.4673 - mean_absolute_error: 1739716.1306 - val_loss: 2480012.5000 - val_mean_absolute_error: 2480012.5000
# Epoch 247/250
# 980/980 [==============================] - 2s 2ms/step - loss: 1962496.5449 - mean_absolute_error: 1962496.8173 - val_loss: 2548635.5000 - val_mean_absolute_error: 2548635.7500
# Epoch 248/250
# 980/980 [==============================] - 2s 2ms/step - loss: 2191453.2500 - mean_absolute_error: 2191453.3806 - val_loss: 3093605.5000 - val_mean_absolute_error: 3093605.5000
# Epoch 249/250
# 980/980 [==============================] - 2s 2ms/step - loss: 2469355.8459 - mean_absolute_error: 2469356.3245 - val_loss: 3237088.7500 - val_mean_absolute_error: 3237090.0000
# Epoch 250/250
# 980/980 [==============================] - 2s 2ms/step - loss: 2760157.1367 - mean_absolute_error: 2760158.2551 - val_loss: 3866070.0000 - val_mean_absolute_error: 3866070.0000

# %% [markdown]
# Let's plot the loss for the testing data versus the learning rate.  We can see that it explodes past a learning rate of 1, so let's focus our window to before this point.

# %%
plt.semilogx(history.history['lr'], history.history['val_loss'])
plt.legend(['Learning Rate', 'Validation Loss'])

# %%
plt.semilogx(history.history['lr'][:140], history.history['loss'][:140])

# %% [markdown]
# It looks like the learning rate of 0.1 seems to work the best.  Let's use that learning rate and train the network this time for real.  Once we train the network, let's predict the prices for the training and test data.

# %%
# Observing the above graph, 0.1 seems to be the best learning rate
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])


optimizer = SGD(lr=0.1, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, validation_data=(X_test_reshape, y_test_reshape))
# Out:
# Train on 980 samples, validate on 246 samples
# Epoch 1/250
# 980/980 [==============================] - 4s 5ms/step - loss: 0.1256 - mean_absolute_error: 0.4262 - val_loss: 0.1478 - val_mean_absolute_error: 0.5369
# Epoch 2/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0376 - mean_absolute_error: 0.2236 - val_loss: 0.0617 - val_mean_absolute_error: 0.3427
# Epoch 3/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0355 - mean_absolute_error: 0.2295 - val_loss: 0.0605 - val_mean_absolute_error: 0.3327
# Epoch 4/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0255 - mean_absolute_error: 0.1927 - val_loss: 0.0322 - val_mean_absolute_error: 0.2359
# Epoch 5/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0159 - mean_absolute_error: 0.1465 - val_loss: 0.0177 - val_mean_absolute_error: 0.1622
# Epoch 6/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0100 - mean_absolute_error: 0.1179 - val_loss: 0.0067 - val_mean_absolute_error: 0.0864
# Epoch 7/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0933 - val_loss: 0.0450 - val_mean_absolute_error: 0.2820
# Epoch 8/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0058 - mean_absolute_error: 0.0882 - val_loss: 0.0315 - val_mean_absolute_error: 0.2307
# Epoch 9/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0748 - val_loss: 0.0203 - val_mean_absolute_error: 0.1775
# Epoch 10/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0701 - val_loss: 0.0222 - val_mean_absolute_error: 0.1882
# Epoch 11/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0639 - val_loss: 0.0386 - val_mean_absolute_error: 0.2594
# Epoch 12/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0592 - val_loss: 0.0238 - val_mean_absolute_error: 0.1970
# Epoch 13/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0583 - val_loss: 0.0221 - val_mean_absolute_error: 0.1882
# Epoch 14/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0554 - val_loss: 0.0250 - val_mean_absolute_error: 0.2035
# Epoch 15/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0566 - val_loss: 0.0266 - val_mean_absolute_error: 0.2109
# Epoch 16/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0538 - val_loss: 0.0191 - val_mean_absolute_error: 0.1735
# Epoch 17/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0524 - val_loss: 0.0195 - val_mean_absolute_error: 0.1760
# Epoch 18/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0524 - val_loss: 0.0218 - val_mean_absolute_error: 0.1886
# Epoch 19/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0526 - val_loss: 0.0184 - val_mean_absolute_error: 0.1706
# Epoch 20/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0514 - val_loss: 0.0172 - val_mean_absolute_error: 0.1638
# Epoch 21/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0511 - val_loss: 0.0178 - val_mean_absolute_error: 0.1683
# Epoch 22/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0505 - val_loss: 0.0174 - val_mean_absolute_error: 0.1659
# Epoch 23/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0499 - val_loss: 0.0151 - val_mean_absolute_error: 0.1525
# Epoch 24/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0495 - val_loss: 0.0156 - val_mean_absolute_error: 0.1557
# Epoch 25/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0494 - val_loss: 0.0153 - val_mean_absolute_error: 0.1542
# Epoch 26/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0490 - val_loss: 0.0143 - val_mean_absolute_error: 0.1479
# Epoch 27/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0486 - val_loss: 0.0140 - val_mean_absolute_error: 0.1465
# Epoch 28/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0483 - val_loss: 0.0145 - val_mean_absolute_error: 0.1500
# Epoch 29/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0480 - val_loss: 0.0128 - val_mean_absolute_error: 0.1387
# Epoch 30/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0477 - val_loss: 0.0130 - val_mean_absolute_error: 0.1406
# Epoch 31/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0474 - val_loss: 0.0130 - val_mean_absolute_error: 0.1409
# Epoch 32/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0472 - val_loss: 0.0125 - val_mean_absolute_error: 0.1375
# Epoch 33/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0469 - val_loss: 0.0115 - val_mean_absolute_error: 0.1308
# Epoch 34/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0467 - val_loss: 0.0124 - val_mean_absolute_error: 0.1371
# Epoch 35/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0466 - val_loss: 0.0113 - val_mean_absolute_error: 0.1297
# Epoch 36/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0462 - val_loss: 0.0108 - val_mean_absolute_error: 0.1258
# Epoch 37/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0462 - val_loss: 0.0118 - val_mean_absolute_error: 0.1339
# Epoch 38/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0457 - val_loss: 0.0103 - val_mean_absolute_error: 0.1224
# Epoch 39/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0458 - val_loss: 0.0100 - val_mean_absolute_error: 0.1205
# Epoch 40/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0456 - val_loss: 0.0112 - val_mean_absolute_error: 0.1300
# Epoch 41/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0018 - mean_absolute_error: 0.0458 - val_loss: 0.0100 - val_mean_absolute_error: 0.1210
# Epoch 42/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0451 - val_loss: 0.0089 - val_mean_absolute_error: 0.1124
# Epoch 43/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0448 - val_loss: 0.0099 - val_mean_absolute_error: 0.1208
# Epoch 44/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0445 - val_loss: 0.0098 - val_mean_absolute_error: 0.1202
# Epoch 45/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0445 - val_loss: 0.0083 - val_mean_absolute_error: 0.1076
# Epoch 46/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0448 - val_loss: 0.0089 - val_mean_absolute_error: 0.1130
# Epoch 47/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0441 - val_loss: 0.0096 - val_mean_absolute_error: 0.1189
# Epoch 48/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0440 - val_loss: 0.0077 - val_mean_absolute_error: 0.1036
# Epoch 49/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0436 - val_loss: 0.0084 - val_mean_absolute_error: 0.1099
# Epoch 50/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0433 - val_loss: 0.0090 - val_mean_absolute_error: 0.1147
# Epoch 51/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0431 - val_loss: 0.0068 - val_mean_absolute_error: 0.0957
# Epoch 52/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0432 - val_loss: 0.0081 - val_mean_absolute_error: 0.1079
# Epoch 53/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0436 - val_loss: 0.0081 - val_mean_absolute_error: 0.1076
# Epoch 54/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0428 - val_loss: 0.0073 - val_mean_absolute_error: 0.1004
# Epoch 55/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0438 - val_loss: 0.0070 - val_mean_absolute_error: 0.0985
# Epoch 56/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0435 - val_loss: 0.0076 - val_mean_absolute_error: 0.1038
# Epoch 57/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0426 - val_loss: 0.0070 - val_mean_absolute_error: 0.0988
# Epoch 58/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0429 - val_loss: 0.0062 - val_mean_absolute_error: 0.0910
# Epoch 59/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0422 - val_loss: 0.0076 - val_mean_absolute_error: 0.1046
# Epoch 60/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0428 - val_loss: 0.0061 - val_mean_absolute_error: 0.0900
# Epoch 61/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0421 - val_loss: 0.0069 - val_mean_absolute_error: 0.0979
# Epoch 62/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0427 - val_loss: 0.0067 - val_mean_absolute_error: 0.0965
# Epoch 63/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0428 - val_loss: 0.0063 - val_mean_absolute_error: 0.0931
# Epoch 64/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0421 - val_loss: 0.0064 - val_mean_absolute_error: 0.0935
# Epoch 65/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0423 - val_loss: 0.0062 - val_mean_absolute_error: 0.0915
# Epoch 66/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0414 - val_loss: 0.0067 - val_mean_absolute_error: 0.0968
# Epoch 67/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0412 - val_loss: 0.0058 - val_mean_absolute_error: 0.0882
# Epoch 68/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0416 - val_loss: 0.0062 - val_mean_absolute_error: 0.0922
# Epoch 69/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0412 - val_loss: 0.0061 - val_mean_absolute_error: 0.0917
# Epoch 70/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0419 - val_loss: 0.0056 - val_mean_absolute_error: 0.0868
# Epoch 71/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0414 - val_loss: 0.0052 - val_mean_absolute_error: 0.0819
# Epoch 72/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0407 - val_loss: 0.0064 - val_mean_absolute_error: 0.0949
# Epoch 73/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0407 - val_loss: 0.0050 - val_mean_absolute_error: 0.0807
# Epoch 74/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0405 - val_loss: 0.0060 - val_mean_absolute_error: 0.0910
# Epoch 75/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0409 - val_loss: 0.0047 - val_mean_absolute_error: 0.0773
# Epoch 76/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0411 - val_loss: 0.0062 - val_mean_absolute_error: 0.0927
# Epoch 77/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0406 - val_loss: 0.0050 - val_mean_absolute_error: 0.0807
# Epoch 78/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0405 - val_loss: 0.0053 - val_mean_absolute_error: 0.0840
# Epoch 79/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0401 - val_loss: 0.0057 - val_mean_absolute_error: 0.0885
# Epoch 80/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0412 - val_loss: 0.0046 - val_mean_absolute_error: 0.0773
# Epoch 81/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0406 - val_loss: 0.0054 - val_mean_absolute_error: 0.0856
# Epoch 82/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0404 - val_loss: 0.0051 - val_mean_absolute_error: 0.0821
# Epoch 83/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0405 - val_loss: 0.0054 - val_mean_absolute_error: 0.0854
# Epoch 84/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0399 - val_loss: 0.0046 - val_mean_absolute_error: 0.0774
# Epoch 85/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0401 - val_loss: 0.0054 - val_mean_absolute_error: 0.0854
# Epoch 86/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0396 - val_loss: 0.0047 - val_mean_absolute_error: 0.0780
# Epoch 87/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0395 - val_loss: 0.0051 - val_mean_absolute_error: 0.0828
# Epoch 88/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0395 - val_loss: 0.0051 - val_mean_absolute_error: 0.0831
# Epoch 89/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0396 - val_loss: 0.0043 - val_mean_absolute_error: 0.0745
# Epoch 90/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0396 - val_loss: 0.0055 - val_mean_absolute_error: 0.0865
# Epoch 91/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0775
# Epoch 92/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0395 - val_loss: 0.0051 - val_mean_absolute_error: 0.0830
# Epoch 93/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0393 - val_loss: 0.0048 - val_mean_absolute_error: 0.0802
# Epoch 94/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0392 - val_loss: 0.0042 - val_mean_absolute_error: 0.0732
# Epoch 95/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0392 - val_loss: 0.0051 - val_mean_absolute_error: 0.0826
# Epoch 96/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0390 - val_loss: 0.0047 - val_mean_absolute_error: 0.0787
# Epoch 97/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0391 - val_loss: 0.0048 - val_mean_absolute_error: 0.0799
# Epoch 98/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0391 - val_loss: 0.0045 - val_mean_absolute_error: 0.0768
# Epoch 99/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0388 - val_loss: 0.0049 - val_mean_absolute_error: 0.0810
# Epoch 100/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0390 - val_loss: 0.0049 - val_mean_absolute_error: 0.0808
# Epoch 101/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0391 - val_loss: 0.0045 - val_mean_absolute_error: 0.0768
# Epoch 102/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0388 - val_loss: 0.0044 - val_mean_absolute_error: 0.0756
# Epoch 103/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0388 - val_loss: 0.0052 - val_mean_absolute_error: 0.0842
# Epoch 104/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0394 - val_loss: 0.0042 - val_mean_absolute_error: 0.0740
# Epoch 105/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0391 - val_loss: 0.0042 - val_mean_absolute_error: 0.0736
# Epoch 106/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0388 - val_loss: 0.0046 - val_mean_absolute_error: 0.0784
# Epoch 107/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0789
# Epoch 108/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0390 - val_loss: 0.0043 - val_mean_absolute_error: 0.0748
# Epoch 109/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0385 - val_loss: 0.0046 - val_mean_absolute_error: 0.0780
# Epoch 110/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0388 - val_loss: 0.0041 - val_mean_absolute_error: 0.0729
# Epoch 111/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0385 - val_loss: 0.0048 - val_mean_absolute_error: 0.0809
# Epoch 112/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0383 - val_loss: 0.0041 - val_mean_absolute_error: 0.0727
# Epoch 113/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0381 - val_loss: 0.0042 - val_mean_absolute_error: 0.0745
# Epoch 114/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0386 - val_loss: 0.0048 - val_mean_absolute_error: 0.0810
# Epoch 115/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0386 - val_loss: 0.0036 - val_mean_absolute_error: 0.0673
# Epoch 116/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0390 - val_loss: 0.0047 - val_mean_absolute_error: 0.0804
# Epoch 117/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0384 - val_loss: 0.0047 - val_mean_absolute_error: 0.0798
# Epoch 118/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0387 - val_loss: 0.0041 - val_mean_absolute_error: 0.0733
# Epoch 119/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0380 - val_loss: 0.0047 - val_mean_absolute_error: 0.0803
# Epoch 120/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0378 - val_loss: 0.0041 - val_mean_absolute_error: 0.0734
# Epoch 121/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0382 - val_loss: 0.0042 - val_mean_absolute_error: 0.0746
# Epoch 122/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0378 - val_loss: 0.0042 - val_mean_absolute_error: 0.0749
# Epoch 123/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0380 - val_loss: 0.0045 - val_mean_absolute_error: 0.0776
# Epoch 124/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0378 - val_loss: 0.0038 - val_mean_absolute_error: 0.0695
# Epoch 125/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0376 - val_loss: 0.0046 - val_mean_absolute_error: 0.0793
# Epoch 126/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0378 - val_loss: 0.0043 - val_mean_absolute_error: 0.0763
# Epoch 127/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0378 - val_loss: 0.0039 - val_mean_absolute_error: 0.0710
# Epoch 128/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0378 - val_loss: 0.0042 - val_mean_absolute_error: 0.0748
# Epoch 129/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0373 - val_loss: 0.0044 - val_mean_absolute_error: 0.0772
# Epoch 130/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0375 - val_loss: 0.0039 - val_mean_absolute_error: 0.0709
# Epoch 131/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0376 - val_loss: 0.0043 - val_mean_absolute_error: 0.0758
# Epoch 132/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0377 - val_loss: 0.0041 - val_mean_absolute_error: 0.0740
# Epoch 133/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0379 - val_loss: 0.0040 - val_mean_absolute_error: 0.0730
# Epoch 134/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0374 - val_loss: 0.0042 - val_mean_absolute_error: 0.0745
# Epoch 135/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0370 - val_loss: 0.0043 - val_mean_absolute_error: 0.0760
# Epoch 136/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0374 - val_loss: 0.0038 - val_mean_absolute_error: 0.0708
# Epoch 137/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0373 - val_loss: 0.0040 - val_mean_absolute_error: 0.0730
# Epoch 138/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0373 - val_loss: 0.0043 - val_mean_absolute_error: 0.0759
# Epoch 139/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0378 - val_loss: 0.0034 - val_mean_absolute_error: 0.0653
# Epoch 140/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0374 - val_loss: 0.0053 - val_mean_absolute_error: 0.0869
# Epoch 141/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0382 - val_loss: 0.0030 - val_mean_absolute_error: 0.0608
# Epoch 142/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0370 - val_loss: 0.0048 - val_mean_absolute_error: 0.0815
# Epoch 143/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0369 - val_loss: 0.0034 - val_mean_absolute_error: 0.0661
# Epoch 144/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0367 - val_loss: 0.0042 - val_mean_absolute_error: 0.0755
# Epoch 145/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0372 - val_loss: 0.0041 - val_mean_absolute_error: 0.0738
# Epoch 146/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0367 - val_loss: 0.0035 - val_mean_absolute_error: 0.0676
# Epoch 147/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0368 - val_loss: 0.0044 - val_mean_absolute_error: 0.0780
# Epoch 148/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0363 - val_loss: 0.0035 - val_mean_absolute_error: 0.0675
# Epoch 149/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0372 - val_loss: 0.0037 - val_mean_absolute_error: 0.0703
# Epoch 150/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0380 - val_loss: 0.0046 - val_mean_absolute_error: 0.0806
# Epoch 151/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0383 - val_loss: 0.0030 - val_mean_absolute_error: 0.0605
# Epoch 152/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0374 - val_loss: 0.0046 - val_mean_absolute_error: 0.0805
# Epoch 153/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0367 - val_loss: 0.0035 - val_mean_absolute_error: 0.0674
# Epoch 154/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0372 - val_loss: 0.0042 - val_mean_absolute_error: 0.0755
# Epoch 155/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0369 - val_loss: 0.0036 - val_mean_absolute_error: 0.0687
# Epoch 156/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0364 - val_loss: 0.0039 - val_mean_absolute_error: 0.0729
# Epoch 157/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0371 - val_loss: 0.0040 - val_mean_absolute_error: 0.0738
# Epoch 158/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0383 - val_loss: 0.0033 - val_mean_absolute_error: 0.0650
# Epoch 159/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0363 - val_loss: 0.0046 - val_mean_absolute_error: 0.0801
# Epoch 160/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0365 - val_loss: 0.0032 - val_mean_absolute_error: 0.0636
# Epoch 161/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0360 - val_loss: 0.0043 - val_mean_absolute_error: 0.0771
# Epoch 162/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0363 - val_loss: 0.0037 - val_mean_absolute_error: 0.0705
# Epoch 163/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0359 - val_loss: 0.0035 - val_mean_absolute_error: 0.0679
# Epoch 164/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0363 - val_loss: 0.0041 - val_mean_absolute_error: 0.0752
# Epoch 165/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0370 - val_loss: 0.0034 - val_mean_absolute_error: 0.0665
# Epoch 166/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0358 - val_loss: 0.0046 - val_mean_absolute_error: 0.0804
# Epoch 167/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0358 - val_loss: 0.0030 - val_mean_absolute_error: 0.0616
# Epoch 168/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0364 - val_loss: 0.0038 - val_mean_absolute_error: 0.0718
# Epoch 169/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0357 - val_loss: 0.0042 - val_mean_absolute_error: 0.0764
# Epoch 170/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0360 - val_loss: 0.0034 - val_mean_absolute_error: 0.0662
# Epoch 171/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0360 - val_loss: 0.0039 - val_mean_absolute_error: 0.0727
# Epoch 172/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0360 - val_loss: 0.0033 - val_mean_absolute_error: 0.0657
# Epoch 173/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0358 - val_loss: 0.0045 - val_mean_absolute_error: 0.0800
# Epoch 174/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0366 - val_loss: 0.0031 - val_mean_absolute_error: 0.0627
# Epoch 175/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0356 - val_loss: 0.0040 - val_mean_absolute_error: 0.0747
# Epoch 176/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0353 - val_loss: 0.0032 - val_mean_absolute_error: 0.0650
# Epoch 177/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0354 - val_loss: 0.0039 - val_mean_absolute_error: 0.0729
# Epoch 178/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0353 - val_loss: 0.0036 - val_mean_absolute_error: 0.0691
# Epoch 179/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0352 - val_loss: 0.0035 - val_mean_absolute_error: 0.0679
# Epoch 180/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0350 - val_loss: 0.0042 - val_mean_absolute_error: 0.0768
# Epoch 181/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0352 - val_loss: 0.0031 - val_mean_absolute_error: 0.0637
# Epoch 182/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0355 - val_loss: 0.0040 - val_mean_absolute_error: 0.0744
# Epoch 183/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0358 - val_loss: 0.0030 - val_mean_absolute_error: 0.0625
# Epoch 184/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0355 - val_loss: 0.0039 - val_mean_absolute_error: 0.0732
# Epoch 185/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0352 - val_loss: 0.0033 - val_mean_absolute_error: 0.0664
# Epoch 186/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0350 - val_loss: 0.0036 - val_mean_absolute_error: 0.0694
# Epoch 187/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0355 - val_loss: 0.0032 - val_mean_absolute_error: 0.0652
# Epoch 188/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0350 - val_loss: 0.0034 - val_mean_absolute_error: 0.0674
# Epoch 189/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0350 - val_loss: 0.0035 - val_mean_absolute_error: 0.0692
# Epoch 190/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0349 - val_loss: 0.0031 - val_mean_absolute_error: 0.0639
# Epoch 191/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0346 - val_loss: 0.0038 - val_mean_absolute_error: 0.0730
# Epoch 192/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0346 - val_loss: 0.0034 - val_mean_absolute_error: 0.0671
# Epoch 193/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0344 - val_loss: 0.0035 - val_mean_absolute_error: 0.0684
# Epoch 194/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0352 - val_loss: 0.0031 - val_mean_absolute_error: 0.0643
# Epoch 195/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0355 - val_loss: 0.0030 - val_mean_absolute_error: 0.0630
# Epoch 196/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0347 - val_loss: 0.0039 - val_mean_absolute_error: 0.0737
# Epoch 197/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0357 - val_loss: 0.0030 - val_mean_absolute_error: 0.0630
# Epoch 198/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0354 - val_loss: 0.0033 - val_mean_absolute_error: 0.0665
# Epoch 199/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0345 - val_loss: 0.0040 - val_mean_absolute_error: 0.0750
# Epoch 200/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0354 - val_loss: 0.0029 - val_mean_absolute_error: 0.0616
# Epoch 201/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0361 - val_loss: 0.0036 - val_mean_absolute_error: 0.0702
# Epoch 202/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0355 - val_loss: 0.0036 - val_mean_absolute_error: 0.0707
# Epoch 203/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0350 - val_loss: 0.0031 - val_mean_absolute_error: 0.0644
# Epoch 204/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0346 - val_loss: 0.0034 - val_mean_absolute_error: 0.0684
# Epoch 205/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0340 - val_loss: 0.0035 - val_mean_absolute_error: 0.0692
# Epoch 206/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0342 - val_loss: 0.0031 - val_mean_absolute_error: 0.0637
# Epoch 207/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0340 - val_loss: 0.0036 - val_mean_absolute_error: 0.0702
# Epoch 208/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0346 - val_loss: 0.0037 - val_mean_absolute_error: 0.0718
# Epoch 209/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0347 - val_loss: 0.0027 - val_mean_absolute_error: 0.0582
# Epoch 210/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0343 - val_loss: 0.0042 - val_mean_absolute_error: 0.0781
# Epoch 211/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0340 - val_loss: 0.0027 - val_mean_absolute_error: 0.0592
# Epoch 212/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0343 - val_loss: 0.0037 - val_mean_absolute_error: 0.0716
# Epoch 213/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0339 - val_loss: 0.0030 - val_mean_absolute_error: 0.0625
# Epoch 214/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0338 - val_loss: 0.0035 - val_mean_absolute_error: 0.0690
# Epoch 215/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0335 - val_loss: 0.0029 - val_mean_absolute_error: 0.0619
# Epoch 216/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0337 - val_loss: 0.0036 - val_mean_absolute_error: 0.0706
# Epoch 217/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0337 - val_loss: 0.0030 - val_mean_absolute_error: 0.0633
# Epoch 218/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0333 - val_loss: 0.0030 - val_mean_absolute_error: 0.0634
# Epoch 219/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0336 - val_loss: 0.0037 - val_mean_absolute_error: 0.0720
# Epoch 220/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0341 - val_loss: 0.0029 - val_mean_absolute_error: 0.0617
# Epoch 221/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0339 - val_loss: 0.0032 - val_mean_absolute_error: 0.0662
# Epoch 222/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0345 - val_loss: 0.0031 - val_mean_absolute_error: 0.0647
# Epoch 223/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0342 - val_loss: 0.0030 - val_mean_absolute_error: 0.0629
# Epoch 224/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0344 - val_loss: 0.0032 - val_mean_absolute_error: 0.0666
# Epoch 225/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0342 - val_loss: 0.0031 - val_mean_absolute_error: 0.0651
# Epoch 226/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0360 - val_loss: 0.0035 - val_mean_absolute_error: 0.0701
# Epoch 227/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0363 - val_loss: 0.0029 - val_mean_absolute_error: 0.0620
# Epoch 228/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0356 - val_loss: 0.0033 - val_mean_absolute_error: 0.0678
# Epoch 229/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0349 - val_loss: 0.0036 - val_mean_absolute_error: 0.0704
# Epoch 230/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0389 - val_loss: 0.0030 - val_mean_absolute_error: 0.0633
# Epoch 231/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0378 - val_loss: 0.0031 - val_mean_absolute_error: 0.0647
# Epoch 232/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0365 - val_loss: 0.0034 - val_mean_absolute_error: 0.0688
# Epoch 233/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0348 - val_loss: 0.0033 - val_mean_absolute_error: 0.0671
# Epoch 234/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0341 - val_loss: 0.0030 - val_mean_absolute_error: 0.0638
# Epoch 235/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0345 - val_loss: 0.0032 - val_mean_absolute_error: 0.0667
# Epoch 236/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0333 - val_loss: 0.0031 - val_mean_absolute_error: 0.0653
# Epoch 237/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0337 - val_loss: 0.0032 - val_mean_absolute_error: 0.0664
# Epoch 238/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0332 - val_loss: 0.0030 - val_mean_absolute_error: 0.0631
# Epoch 239/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0327 - val_loss: 0.0037 - val_mean_absolute_error: 0.0721
# Epoch 240/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0338 - val_loss: 0.0029 - val_mean_absolute_error: 0.0618
# Epoch 241/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0330 - val_loss: 0.0031 - val_mean_absolute_error: 0.0655
# Epoch 242/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.8806e-04 - mean_absolute_error: 0.0326 - val_loss: 0.0032 - val_mean_absolute_error: 0.0668
# Epoch 243/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.9370e-04 - mean_absolute_error: 0.0326 - val_loss: 0.0031 - val_mean_absolute_error: 0.0652
# Epoch 244/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.8180e-04 - mean_absolute_error: 0.0327 - val_loss: 0.0028 - val_mean_absolute_error: 0.0617
# Epoch 245/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.8084e-04 - mean_absolute_error: 0.0324 - val_loss: 0.0033 - val_mean_absolute_error: 0.0679
# Epoch 246/250
# 980/980 [==============================] - 2s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0327 - val_loss: 0.0031 - val_mean_absolute_error: 0.0646
# Epoch 247/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.8839e-04 - mean_absolute_error: 0.0328 - val_loss: 0.0029 - val_mean_absolute_error: 0.0620
# Epoch 248/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.8610e-04 - mean_absolute_error: 0.0327 - val_loss: 0.0032 - val_mean_absolute_error: 0.0663
# Epoch 249/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.8502e-04 - mean_absolute_error: 0.0325 - val_loss: 0.0027 - val_mean_absolute_error: 0.0606
# Epoch 250/250
# 980/980 [==============================] - 2s 2ms/step - loss: 9.7496e-04 - mean_absolute_error: 0.0323 - val_loss: 0.0034 - val_mean_absolute_error: 0.0691

# %% [markdown]
# Once we predict the values, we also must *reverse* the normalization so that we can plot the predictions in the same scale as the original values.

# %%
y_pred_train_keras = scaler.inverse_transform(keras_model.predict(X_train_reshape, batch_size=256))
y_pred_keras = scaler.inverse_transform(keras_model.predict(X_test_reshape, batch_size=256))

# %% [markdown]
# Let's now plot what the training and test predictions look like and compare witht he original values.

# %%
# Plot what it looks like for the training data
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_keras['Adj Close Train'] = y_pred_train_keras[:-window_size]
df_keras.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again, quite accurate... and now for the test data.

# %%
# Same for the test
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_keras['Adj Close Test'] = y_pred_keras
df_keras.plot(label='GE', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# I have more confidence in the neural network approach as it seems to indicate would the trend would be like when the data is noise free.  We can also see a more smoother transition between points of high curvature.
#
# Finally to see how everything performs, let's plot all of the methods together for both the training and testing data.

# %%
df_train = df.copy()
df_train.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_train = df_train.iloc[window_size:ind_split] # Past 32 days we don't know yet
# Add in all of our methods
df_train['Adj Close Train Ridge'] = y_pred_train_ridge[:-window_size]
df_train['Adj Close Train Gradient Boosting'] = y_pred_train_gb[:-window_size]
df_train['Adj Close Train LSTM'] = y_pred_train_keras[:-window_size]
# Plot the data now
df_train.plot(label='GE', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Cool.  They all more or less follow the same trend... and now for the testing data.
#
# 1.   List item
# 2.   List item

# %%
df_test = df.copy()
df_test.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_test = df_test.iloc[ind_split+window_size:] # Past 32 days we don't know yet
# Add in all of our methods
df_test['Adj Close Test Ridge'] = y_pred_ridge
df_test['Adj Close Test Gradient Boosting'] = y_pred_gb
df_test['Adj Close Test LSTM'] = y_pred_keras
# Plot the data now
df_test.plot(label='GE', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# So here's where it gets interesting.  We can see that the neural network based method is what the values would be when there's no presence of noise.  The ridge regression based method seems to follow the trend the best with the noise modelled in.  The gradient boosting method also follows the same trend, but because the method does not use interpolation, points of very high curvature tend to be the most inaccurate.

# %% [markdown]
# # So what happens if we don't have testing data to try out?
#
# Good question.  What you can do take the learned model that you have, then start with the last $N$ values in your data (in my case 32), and start predicting what the next values will be.  With the next values, keep using the previous $N$ values for your desired forecasting.
#
# We already have our learned models above, so let's go ahead and do that.

# %%
num_days = 10 # Let's try and forecase the next 10 days or two years

# Get the last window_size (32) days
data_seed = df['Adj Close'].values[-window_size:][None]
# Get the normalized data as well for the neural network
data_seed_norm = scaler.transform(data_seed)
input_values = {"ridge": data_seed, "gb": data_seed, "keras": data_seed_norm.copy()}
values = {"ridge": [], "gb": [], "keras": []}
for i in range(num_days): # For each day...
    # Predict the next price given the previous N prices
    values["ridge"].append(ridge_model.predict(input_values["ridge"])[0])
    values["gb"].append(gb_model.predict(input_values["gb"])[0])
    values["keras"].append(keras_model.predict(input_values["keras"][...,None])[0][0])

    # Dump the oldest price and put the newest price at the end
    for v in input_values:
        val = input_values[v]
        val = np.insert(val, -1, values[v][-1], axis=1)
        val = np.delete(val, 0, axis=1)
        input_values[v] = val.copy()

# Convert all to NumPy arrays
for v in input_values:
    values[v] = np.array(values[v])

# Unnormalize prices from NN approach
values["keras"] = scaler.inverse_transform(values["keras"][None])[0]

# %% [markdown]
# Now let's plot the next 10 days worth of data

# %%
from datetime import timedelta, datetime
last_date = datetime.strptime(df.index[-1], '%Y-%m-%d')
df_forecast = pd.DataFrame()
df_forecast["Ridge"] = values["ridge"]
df_forecast["Gradient Boosting"] = values["gb"]
df_forecast["Keras LSTM"] = values["keras"]
df_forecast.index = pd.date_range(start=last_date, periods=num_days)
df_forecast.plot(label='GE', figsize=(16,8), title='Forecasted Adjusted Closing Price', grid=True)

# %% [markdown]
# #GE is currently trading at $8.80 Sept 4, 2019 so this looks like a buy
